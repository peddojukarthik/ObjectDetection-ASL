# %%
import os

# %%
CUSTOM_MODEL_NAME = 'my_sdd_mobnet'
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz'
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
LABEL_MAP_NAME = 'label_map.pbtxt'

# %%
paths = {
    'PROJECT_PATH': os.path.join('project'),
    'SCRIPT_PATH': os.path.join('scripts'),
    'APIMODEL_PATH': os.path.join('modelsNEW'),
    'ANNOTATION_PATH': os.path.join('project','annotations'),
    'IMAGE_PATH': os.path.join('project','images'),
    'MODEL_PATH': os.path.join('project','modelsNEW'),
    'PRETRAINED_MODEL_PATH': os.path.join('project','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('project','modelsNEW',CUSTOM_MODEL_NAME),
    'OUTPUT_PATH': os.path.join('project','modelsNEW',CUSTOM_MODEL_NAME,'export'),
    'TFJS_PATH': os.path.join('project','modelsNEW',CUSTOM_MODEL_NAME,'tfjsexport'),
    'TFLITE_PATH': os.path.join('project','modelsNEW',CUSTOM_MODEL_NAME,'tfliteexport'),
    'PROTOC_PATH': os.path.join('protoc')
}

# %%
files = {
    'PIPELINE_CONFIG': os.path.join('project','modelsNEW',CUSTOM_MODEL_NAME,'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPT_PATH'],TF_RECORD_SCRIPT_NAME),
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME),
    'ASL_LABELMAP': os.path.join(paths['ANNOTATION_PATH'],'asl_label_map.pbtxt')
}

# %%
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'posix':
            # !mkdir -p {path}
        if os.name == 'nt':
            # !mkdir {path}

# %%
if os.name == 'nt':
    import wget

# %%
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}

# %%
if os.name == 'posix':
    # !apt-get install protobuf-compiler
    # !cd sign-detection/modelsNEW/research && protoc object_detection/protos/*.proto --python_outs=. && cp object_detection/packages/tf2/setup.py . && python -m pip install .
if os.name == 'nt':
    url="https://github.com/protocolbuffers/protobuf/releases/download/v3.19.6/protoc-3.19.6-win64.zip"
    wget.download(url)
    # !move protoc-3.19.6-win64.zip {paths['PROTOC_PATH']}
    # !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.19.6-win64.zip
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))
    # !cd sign-detection/modelsNEW/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py && python -m pip install . 
    # !cd sign-detection/modelsNEW/research/slim && pip install -e .
# Out:
# 100% [..........................................................................] 1523222 / 1523222        1 file(s) moved.
#         1 file(s) copied.
# Processing d:\sign-detection\sign-detection\modelsnew\research
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: avro-python3 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from object_detection==0.1) (1.10.2)
# Requirement already satisfied: apache-beam in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from object_detection==0.1) (2.46.0)
# Requirement already satisfied: pillow in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from object_detection==0.1) (11.3.0)
# Requirement already satisfied: lxml in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from object_detection==0.1) (6.0.0)
# Requirement already satisfied: matplotlib in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from object_detection==0.1) (3.9.4)
# Requirement already satisfied: Cython in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from object_detection==0.1) (3.1.2)
# Requirement already satisfied: contextlib2 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from object_detection==0.1) (21.6.0)
# Requirement already satisfied: tf-slim in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from object_detection==0.1) (1.1.0)
# Requirement already satisfied: six in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from object_detection==0.1) (1.17.0)
# Requirement already satisfied: pycocotools in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from object_detection==0.1) (2.0.10)
# Requirement already satisfied: lvis in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from object_detection==0.1) (0.5.3)
# Requirement already satisfied: scipy in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from object_detection==0.1) (1.13.1)
# Requirement already satisfied: pandas in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from object_detection==0.1) (2.3.1)
# Requirement already satisfied: tf-models-official>=2.5.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from object_detection==0.1) (2.10.0)
# Requirement already satisfied: tensorflow_io in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from object_detection==0.1) (0.27.0)
# Requirement already satisfied: keras in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from object_detection==0.1) (2.10.0)
# Requirement already satisfied: pyparsing==2.4.7 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from object_detection==0.1) (2.4.7)
# Requirement already satisfied: sacrebleu<=2.2.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from object_detection==0.1) (2.2.0)
# Requirement already satisfied: portalocker in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from sacrebleu<=2.2.0->object_detection==0.1) (3.2.0)
# Requirement already satisfied: regex in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from sacrebleu<=2.2.0->object_detection==0.1) (2024.11.6)
# Requirement already satisfied: tabulate>=0.8.9 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from sacrebleu<=2.2.0->object_detection==0.1) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from sacrebleu<=2.2.0->object_detection==0.1) (1.24.4)
# Requirement already satisfied: colorama in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from sacrebleu<=2.2.0->object_detection==0.1) (0.4.6)
# Requirement already satisfied: gin-config in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tf-models-official>=2.5.1->object_detection==0.1) (0.5.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tf-models-official>=2.5.1->object_detection==0.1) (2.177.0)
# Requirement already satisfied: immutabledict in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tf-models-official>=2.5.1->object_detection==0.1) (4.2.1)
# Requirement already satisfied: kaggle>=1.3.9 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tf-models-official>=2.5.1->object_detection==0.1) (1.7.4.5)
# Requirement already satisfied: oauth2client in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tf-models-official>=2.5.1->object_detection==0.1) (4.1.3)
# Requirement already satisfied: opencv-python-headless==4.5.2.52 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tf-models-official>=2.5.1->object_detection==0.1) (4.5.2.52)
# Requirement already satisfied: psutil>=5.4.3 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tf-models-official>=2.5.1->object_detection==0.1) (7.0.0)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tf-models-official>=2.5.1->object_detection==0.1) (9.0.0)
# Requirement already satisfied: pyyaml<6.0,>=5.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tf-models-official>=2.5.1->object_detection==0.1) (5.4.1)
# Requirement already satisfied: sentencepiece in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tf-models-official>=2.5.1->object_detection==0.1) (0.2.0)
# Requirement already satisfied: seqeval in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tf-models-official>=2.5.1->object_detection==0.1) (1.2.2)
# Requirement already satisfied: tensorflow-addons in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tf-models-official>=2.5.1->object_detection==0.1) (0.22.0)
# Requirement already satisfied: tensorflow-datasets in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tf-models-official>=2.5.1->object_detection==0.1) (4.9.0)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tf-models-official>=2.5.1->object_detection==0.1) (0.16.1)
# Requirement already satisfied: tensorflow-model-optimization>=0.4.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tf-models-official>=2.5.1->object_detection==0.1) (0.8.0)
# Requirement already satisfied: tensorflow-text~=2.10.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tf-models-official>=2.5.1->object_detection==0.1) (2.10.0)
# Requirement already satisfied: tensorflow~=2.10.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tf-models-official>=2.5.1->object_detection==0.1) (2.10.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (25.2.10)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (3.14.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (3.4.0)
# Requirement already satisfied: packaging in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (23.2)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (3.19.6)
# Requirement already satisfied: setuptools in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (78.1.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (1.14.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (0.27.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (1.74.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (2.10.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (2.10.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (2.40.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (3.8.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (2.32.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (3.1.3)
# Requirement already satisfied: wheel>=0.26 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (0.45.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (2025.7.14)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (0.6.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object_detection==0.1) (0.21.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object_detection==0.1) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object_detection==0.1) (2.25.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object_detection==0.1) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object_detection==0.1) (1.63.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object_detection==0.1) (1.26.1)
# Requirement already satisfied: bleach in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object_detection==0.1) (6.2.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object_detection==0.1) (2.9.0.post0)
# Requirement already satisfied: python-slugify in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object_detection==0.1) (8.0.4)
# Requirement already satisfied: text-unidecode in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object_detection==0.1) (1.3)
# Requirement already satisfied: tqdm in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object_detection==0.1) (4.67.1)
# Requirement already satisfied: webencodings in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object_detection==0.1) (0.5.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (3.23.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from pandas->object_detection==0.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from pandas->object_detection==0.1) (2025.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (3.3.1)
# Requirement already satisfied: tf-keras>=2.14.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow-hub>=0.6.0->tf-models-official>=2.5.1->object_detection==0.1) (2.15.0)
# Requirement already satisfied: dm-tree~=0.1.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official>=2.5.1->object_detection==0.1) (0.1.8)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object_detection==0.1) (3.0.2)
# Requirement already satisfied: crcmod<2.0,>=1.7 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from apache-beam->object_detection==0.1) (1.7)
# Requirement already satisfied: orjson<4.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from apache-beam->object_detection==0.1) (3.11.1)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from apache-beam->object_detection==0.1) (0.3.1.1)
# Requirement already satisfied: cloudpickle~=2.2.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from apache-beam->object_detection==0.1) (2.2.1)
# Requirement already satisfied: fastavro<2,>=0.23.6 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from apache-beam->object_detection==0.1) (1.11.1)
# Requirement already satisfied: fasteners<1.0,>=0.3 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from apache-beam->object_detection==0.1) (0.19)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from apache-beam->object_detection==0.1) (2.7.3)
# Requirement already satisfied: objsize<0.7.0,>=0.6.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from apache-beam->object_detection==0.1) (0.6.1)
# Requirement already satisfied: pymongo<4.0.0,>=3.8.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from apache-beam->object_detection==0.1) (3.13.0)
# Requirement already satisfied: pydot<2,>=1.2.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from apache-beam->object_detection==0.1) (1.4.2)
# Requirement already satisfied: zstandard<1,>=0.18.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from apache-beam->object_detection==0.1) (0.23.0)
# Requirement already satisfied: pyarrow<10.0.0,>=3.0.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from apache-beam->object_detection==0.1) (9.0.0)
# Requirement already satisfied: docopt in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam->object_detection==0.1) (0.6.2)
# Requirement already satisfied: cycler>=0.10.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from lvis->object_detection==0.1) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.1.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from lvis->object_detection==0.1) (1.4.7)
# Requirement already satisfied: opencv-python>=4.1.0.25 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from lvis->object_detection==0.1) (4.11.0.86)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from matplotlib->object_detection==0.1) (1.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from matplotlib->object_detection==0.1) (4.59.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from matplotlib->object_detection==0.1) (6.5.2)
# Requirement already satisfied: pywin32>=226 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from portalocker->sacrebleu<=2.2.0->object_detection==0.1) (311)
# Requirement already satisfied: scikit-learn>=0.21.3 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from seqeval->tf-models-official>=2.5.1->object_detection==0.1) (1.6.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object_detection==0.1) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object_detection==0.1) (3.6.0)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow-addons->tf-models-official>=2.5.1->object_detection==0.1) (2.13.3)
# Requirement already satisfied: array-record in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object_detection==0.1) (0.4.1)
# Requirement already satisfied: click in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object_detection==0.1) (8.1.8)
# Requirement already satisfied: etils>=0.9.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets->tf-models-official>=2.5.1->object_detection==0.1) (1.5.2)
# Requirement already satisfied: promise in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object_detection==0.1) (2.3)
# Requirement already satisfied: tensorflow-metadata in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object_detection==0.1) (1.13.0)
# Requirement already satisfied: toml in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object_detection==0.1) (0.10.2)
# Requirement already satisfied: fsspec in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets->tf-models-official>=2.5.1->object_detection==0.1) (2025.7.0)
# Building wheels for collected packages: object_detection
#   Building wheel for object_detection (setup.py): started
#   Building wheel for object_detection (setup.py): finished with status 'done'
#   Created wheel for object_detection: filename=object_detection-0.1-py3-none-any.whl size=1708899 sha256=c6e73870301b49a6d5a945c7775341a327a20c6075736cf1970fc3d6e607808d
#   Stored in directory: C:\Users\karthik\AppData\Local\Temp\pip-ephem-wheel-cache-yk13rp7h\wheels\6a\81\1a\3ea21251011d2c967f3a3ced5a6e94b3193fb24a5918ba6021
# Successfully built object_detection
# Installing collected packages: object_detection
#   Attempting uninstall: object_detection
#     Found existing installation: object_detection 0.1
#     Uninstalling object_detection-0.1:
#       Successfully uninstalled object_detection-0.1
# Successfully installed object_detection-0.1
#   DEPRECATION: Building 'object_detection' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'object_detection'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# Obtaining file:///D:/sign-detection/sign-detection/modelsNEW/research/slim
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: six in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from slim==0.1) (1.17.0)
# Requirement already satisfied: tf-slim>=1.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from slim==0.1) (1.1.0)
# Requirement already satisfied: absl-py>=0.2.2 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tf-slim>=1.1->slim==0.1) (1.4.0)
# Installing collected packages: slim
#   Attempting uninstall: slim
#     Found existing installation: slim 0.1
#     Uninstalling slim-0.1:
#       Successfully uninstalled slim-0.1
#   Running setup.py develop for slim
# Successfully installed slim
#   DEPRECATION: Legacy editable install of slim==0.1 from file:///D:/sign-detection/sign-detection/modelsNEW/research/slim (setup.py develop) is deprecated. pip 25.3 will enforce this behaviour change. A possible replacement is to add a pyproject.toml or enable --use-pep517, and use setuptools >= 64. If the resulting installation is not behaving as expected, try using --config-settings editable_mode=compat. Please consult the setuptools documentation for more information. Discussion can be found at https://github.com/pypa/pip/issues/11457

# %%
 # !cd sign-detection/modelsNEW/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py && python -m pip install . 
 # !cd sign-detection/modelsNEW/research/slim && pip install -e .

# %%
VERIFICATION_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'builders', 'model_builder_tf2_test.py')
# !python {VERIFICATION_SCRIPT}
# Out:
# Running tests under Python 3.9.23: C:\Users\karthik\.conda\envs\gpuenv\python.exe
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# C:\Users\karthik\.conda\envs\gpuenv\lib\site-packages\object_detection\builders\model_builder.py:1112: DeprecationWarning: The 'warn' function is deprecated, use 'warning' instead
#   logging.warn(('Building experimental DeepMAC meta-arch.'
# W1008 22:59:32.197178 11436 model_builder.py:1112] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 2.18s
# I1008 22:59:32.741429 11436 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 2.18s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 4.36s
# I1008 22:59:37.107345 11436 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 4.36s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.57s
# I1008 22:59:37.675967 11436 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.57s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.52s
# I1008 22:59:38.196094 11436 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.52s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 5.12s
# I1008 22:59:43.321388 11436 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 5.12s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I1008 22:59:43.332562 11436 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.06s
# I1008 23:00:24.178816 11436 efficientnet_model.py:143] round_filter input=80 output=144
# I1008 23:00:26.364822 11436 efficientnet_model.py:143] round_filter input=80 output=144
# I1008 23:00:26.365819 11436 efficientnet_model.py:143] round_filter input=112 output=200
# I1008 23:00:28.057747 11436 efficientnet_model.py:143] round_filter input=112 output=200
# I1008 23:00:28.058645 11436 efficientnet_model.py:143] round_filter input=192 output=344
# I1008 23:00:30.366732 11436 efficientnet_model.py:143] round_filter input=192 output=344
# I1008 23:00:30.366732 11436 efficientnet_model.py:143] round_filter input=320 output=576
# I1008 23:00:31.007882 11436 efficientnet_model.py:143] round_filter input=1280 output=2304
# I1008 23:00:31.092362 11436 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1008 23:00:31.321182 11436 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b7
# I1008 23:00:31.322191 11436 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 384
# I1008 23:00:31.322191 11436 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 8
# I1008 23:00:31.325182 11436 efficientnet_model.py:143] round_filter input=32 output=64
# I1008 23:00:31.370566 11436 efficientnet_model.py:143] round_filter input=32 output=64
# I1008 23:00:31.370566 11436 efficientnet_model.py:143] round_filter input=16 output=32
# I1008 23:00:32.029844 11436 efficientnet_model.py:143] round_filter input=16 output=32
# I1008 23:00:32.029844 11436 efficientnet_model.py:143] round_filter input=24 output=48
# I1008 23:00:33.444300 11436 efficientnet_model.py:143] round_filter input=24 output=48
# I1008 23:00:33.445297 11436 efficientnet_model.py:143] round_filter input=40 output=80
# I1008 23:00:34.891281 11436 efficientnet_model.py:143] round_filter input=40 output=80
# I1008 23:00:34.891281 11436 efficientnet_model.py:143] round_filter input=80 output=160
# I1008 23:00:36.947243 11436 efficientnet_model.py:143] round_filter input=80 output=160
# I1008 23:00:36.947243 11436 efficientnet_model.py:143] round_filter input=112 output=224
# I1008 23:00:39.017762 11436 efficientnet_model.py:143] round_filter input=112 output=224
# I1008 23:00:39.017762 11436 efficientnet_model.py:143] round_filter input=192 output=384
# I1008 23:00:41.711458 11436 efficientnet_model.py:143] round_filter input=192 output=384
# I1008 23:00:41.711458 11436 efficientnet_model.py:143] round_filter input=320 output=640
# I1008 23:00:42.568809 11436 efficientnet_model.py:143] round_filter input=1280 output=2560
# I1008 23:00:42.665115 11436 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 58.91s
# I1008 23:00:43.491125 11436 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 58.91s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I1008 23:00:43.540360 11436 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I1008 23:00:43.544271 11436 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I1008 23:00:43.545253 11436 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I1008 23:00:43.548360 11436 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I1008 23:00:43.551233 11436 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I1008 23:00:43.552247 11436 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I1008 23:00:43.554349 11436 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 72.998s
#
# OK (skipped=1)

# %%
import object_detection

# %%
if os.name == 'posix':
    # !wget (PRETRAINED_MODEL_URL)
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
if os.name == 'nt':
    wget.download (PRETRAINED_MODEL_URL)
    # !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
# Out:
# 100% [........................................................................] 20515344 / 20515344        1 file(s) moved.
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/checkpoint
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.index
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/saved_model.pb
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.index

# %%
labels = [{'name':'thumbsup','id': 1},{'name':'thumbsdown','id':2},{'name':'thankyou','id':3},{'name':'livelong','id':4}]

with open(files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item {\n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %%
if not os.path.exists(files['TF_RECORD_SCRIPT']):
    # !git clone https://github.com/nicknochnack/GenerateTFRecord {paths['SCRIPT_PATH']}
# Out:
# Cloning into 'scripts'...

# %%
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'],'train')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'train.record')}
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'],'test')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'test.record')}
# Out:
# Successfully created the TFRecord file: sign-detection\project\annotations\train.record
# Successfully created the TFRecord file: sign-detection\project\annotations\test.record

# %%
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'],'ASL_TRAIN')} -l {files['ASL_LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'ASL.train.record')}
# Out:
# Traceback (most recent call last):
#   File "D:\sign-detection-small\scripts\generate_tfrecord.py", line 168, in <module>
#     tf.app.run()
#   File "C:\Users\karthik\.conda\envs\gpuenv\lib\site-packages\tensorflow\python\platform\app.py", line 36, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "C:\Users\karthik\.conda\envs\gpuenv\lib\site-packages\absl\app.py", line 308, in run
#     _run_main(main, args)
#   File "C:\Users\karthik\.conda\envs\gpuenv\lib\site-packages\absl\app.py", line 254, in _run_main
#     sys.exit(main(argv))
#   File "D:\sign-detection-small\scripts\generate_tfrecord.py", line 158, in main
#     tf_example = create_tf_example(group, path)
#   File "D:\sign-detection-small\scripts\generate_tfrecord.py", line 112, in create_tf_example
#     encoded_jpg = fid.read()
#   File "C:\Users\karthik\.conda\envs\gpuenv\lib\site-packages\tensorflow\python\lib\io\file_io.py", line 114, in read
#     self._preread_check()
#   File "C:\Users\karthik\.conda\envs\gpuenv\lib\site-packages\tensorflow\python\lib\io\file_io.py", line 76, in _preread_check
#     self._read_buf = _pywrap_file_io.BufferedInputStream(
# tensorflow.python.framework.errors_impl.NotFoundError: NewRandomAccessFile failed to Create/Open: project\images\ASL_TRAIN\WhatsApp Image 2025-09-29 at 11.05.19_49231b53.jpg : The system cannot find the file specified.
#
# ; No such file or directory

# %%
if os.name == 'posix':
    # !cp {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
if os.name == 'nt':
    # !copy {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
# Out:
#         1 file(s) copied.

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
config = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])

# %%
config
# Out:
# {'model': ssd {
#    num_classes: 90
#    image_resizer {
#      fixed_shape_resizer {
#        height: 320
#        width: 320
#      }
#    }
#    feature_extractor {
#      type: "ssd_mobilenet_v2_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 3.9999998989515007e-05
#          }
#        }
#        initializer {
#          random_normal_initializer {
#            mean: 0.0
#            stddev: 0.009999999776482582
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.996999979019165
#          scale: true
#          epsilon: 0.0010000000474974513
#        }
#      }
#      use_depthwise: true
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#        additional_layer_depth: 128
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10.0
#        x_scale: 10.0
#        height_scale: 5.0
#        width_scale: 5.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 3.9999998989515007e-05
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.009999999776482582
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.996999979019165
#            scale: true
#            epsilon: 0.0010000000474974513
#          }
#        }
#        depth: 128
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.599999904632568
#        share_prediction_tower: true
#        use_depthwise: true
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 9.99999993922529e-09
#        iou_threshold: 0.6000000238418579
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2.0
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  },
#  'train_config': batch_size: 128
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0.0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3.0
#      min_area: 0.75
#      max_area: 1.0
#      overlap_thresh: 0.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.07999999821186066
#          total_steps: 50000
#          warmup_learning_rate: 0.026666000485420227
#          warmup_steps: 1000
#        }
#      }
#      momentum_optimizer_value: 0.8999999761581421
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 50000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false,
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }
#  ],
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "r") as f:
    proto_str = f.read()
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = 29
pipeline_config.train_config.batch_size = 8
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= files['ASL_LABELMAP']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'ASL.train.record')]
pipeline_config.eval_input_reader[0].label_map_path = files['ASL_LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'ASL.test.record')]

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %%
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps=2000".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'])

# %%
print(command)
# Out:
# python modelsNEW\research\object_detection\model_main_tf2.py --model_dir=project\modelsNEW\my_sdd_mobnet --pipeline_config_path=project\modelsNEW\my_sdd_mobnet\pipeline.config --num_train_steps=2000

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])

# %%
print(command)
# Out:
# python modelsNEW\research\object_detection\model_main_tf2.py --model_dir=project\modelsNEW\my_sdd_mobnet --pipeline_config_path=project\modelsNEW\my_sdd_mobnet\pipeline.config --checkpoint_dir=project\modelsNEW\my_sdd_mobnet

# %%
import cv2
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util

import numpy as np

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# !pip list

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# %%
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-4')).expect_partial()

# %%
@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['ASL_LABELMAP'])

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'ASL_TRAIN', 'A482.jpg')

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=5,
            min_score_thresh=.8,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()

# %%
import cv2
import time

# %%
cap = cv2.VideoCapture(0)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

while cap.isOpened(): 
    ret, frame = cap.read()
    
    image_np = np.array(frame)
    
    input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype = tf.float32)
    detections = detect_fn(input_tensor)
    
    num_detections = int(detections.pop('num_detections'))
    detections = {key: value[0, :num_detections].numpy()
                  for key, value in detections.items()}
    detections['num_detections'] = num_detections

    # detection_classes should be ints.
    detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

    label_id_offset = 1
    image_np_with_detections = image_np.copy()

    viz_utils.visualize_boxes_and_labels_on_image_array(
                image_np_with_detections,
                detections['detection_boxes'],
                detections['detection_classes']+label_id_offset,
                detections['detection_scores'],
                category_index,
                use_normalized_coordinates=True,
                max_boxes_to_draw=5,
                min_score_thresh=.8,
                agnostic_mode=False)

    cv2.imshow('object detection',  cv2.resize(image_np_with_detections, (800, 600)))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break

# %%
FREEZE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'exporter_main_v2.py ')

# %%
command = "python {} --input_type=image_tensor --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(FREEZE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['OUTPUT_PATH'])

# %%
print(command)
# Out:
# python sign-detection\modelsNEW\research\object_detection\exporter_main_v2.py  --input_type=image_tensor --pipeline_config_path=sign-detection\project\modelsNEW\my_sdd_mobnet\pipeline.config --trained_checkpoint_dir=sign-detection\project\modelsNEW\my_sdd_mobnet --output_directory=sign-detection\project\modelsNEW\my_sdd_mobnet\export

# %%
# !{command}
# Out:
# WARNING:tensorflow:From C:\Users\karthik\.conda\envs\gpuenv\lib\site-packages\tensorflow\python\autograph\impl\api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0907 19:42:12.406744 21124 deprecation.py:623] From C:\Users\karthik\.conda\envs\gpuenv\lib\site-packages\tensorflow\python\autograph\impl\api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# I0907 19:42:22.146016 21124 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0907 19:42:44.827989 21124 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0907 19:42:56.661916 21124 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x000001DAC30621F0>, because it is not built.
# W0907 19:43:03.015618 21124 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x000001DAC30621F0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x000001DADC28E490>, because it is not built.
# W0907 19:43:03.631266 21124 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x000001DADC28E490>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DAD7617310>, because it is not built.
# W0907 19:43:03.631266 21124 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DAD7617310>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DAD7617550>, because it is not built.
# W0907 19:43:03.631266 21124 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DAD7617550>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x000001DAD7631AC0>, because it is not built.
# W0907 19:43:03.631266 21124 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x000001DAD7631AC0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DAD76311F0>, because it is not built.
# W0907 19:43:03.631266 21124 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DAD76311F0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DAD76319A0>, because it is not built.
# W0907 19:43:03.631266 21124 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DAD76319A0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x000001DADC2435E0>, because it is not built.
# W0907 19:43:03.631266 21124 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x000001DADC2435E0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DADC201B80>, because it is not built.
# W0907 19:43:03.631266 21124 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DADC201B80>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DAC9AEECD0>, because it is not built.
# W0907 19:43:03.631266 21124 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DAC9AEECD0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x000001DADC237EE0>, because it is not built.
# W0907 19:43:03.631266 21124 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x000001DADC237EE0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DADC2378E0>, because it is not built.
# W0907 19:43:03.631266 21124 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DADC2378E0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DAD761E760>, because it is not built.
# W0907 19:43:03.631266 21124 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DAD761E760>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DAD75D9A60>, because it is not built.
# W0907 19:43:03.631266 21124 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DAD75D9A60>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DAD75D99A0>, because it is not built.
# W0907 19:43:03.631266 21124 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DAD75D99A0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DAD7623250>, because it is not built.
# W0907 19:43:03.631266 21124 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DAD7623250>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DADC266790>, because it is not built.
# W0907 19:43:03.631266 21124 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DADC266790>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DADC266670>, because it is not built.
# W0907 19:43:03.647495 21124 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DADC266670>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DADC2667C0>, because it is not built.
# W0907 19:43:03.647495 21124 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DADC2667C0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DAD7656A00>, because it is not built.
# W0907 19:43:03.647495 21124 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DAD7656A00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DAD7656BB0>, because it is not built.
# W0907 19:43:03.647495 21124 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DAD7656BB0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DADC2A5730>, because it is not built.
# W0907 19:43:03.647495 21124 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DADC2A5730>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DADC23D910>, because it is not built.
# W0907 19:43:03.647495 21124 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DADC23D910>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DAD7658CD0>, because it is not built.
# W0907 19:43:03.647495 21124 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DAD7658CD0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DAD7658BE0>, because it is not built.
# W0907 19:43:03.647495 21124 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DAD7658BE0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DAD7658F40>, because it is not built.
# W0907 19:43:03.647495 21124 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DAD7658F40>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DAD76588E0>, because it is not built.
# W0907 19:43:03.647495 21124 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DAD76588E0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DADC2327C0>, because it is not built.
# W0907 19:43:03.647495 21124 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DADC2327C0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DADC2323A0>, because it is not built.
# W0907 19:43:03.647495 21124 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DADC2323A0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DAF93DA2B0>, because it is not built.
# W0907 19:43:03.647495 21124 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DAF93DA2B0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DAF95EFE20>, because it is not built.
# W0907 19:43:03.647495 21124 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DAF95EFE20>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DAD4083040>, because it is not built.
# W0907 19:43:03.647495 21124 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DAD4083040>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DAD4083FD0>, because it is not built.
# W0907 19:43:03.647495 21124 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DAD4083FD0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DAD408E310>, because it is not built.
# W0907 19:43:03.647495 21124 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DAD408E310>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DAD408E2E0>, because it is not built.
# W0907 19:43:03.647495 21124 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DAD408E2E0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DAD408E370>, because it is not built.
# W0907 19:43:03.647495 21124 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DAD408E370>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DAD408E5E0>, because it is not built.
# W0907 19:43:03.647495 21124 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DAD408E5E0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DAC9C28130>, because it is not built.
# W0907 19:43:03.647495 21124 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DAC9C28130>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DAF9341F10>, because it is not built.
# W0907 19:43:03.647495 21124 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DAF9341F10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DADC288F40>, because it is not built.
# W0907 19:43:03.647495 21124 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DADC288F40>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DADC288CD0>, because it is not built.
# W0907 19:43:03.647495 21124 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DADC288CD0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DADC288D60>, because it is not built.
# W0907 19:43:03.647495 21124 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DADC288D60>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DADC2886A0>, because it is not built.
# W0907 19:43:03.647495 21124 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DADC2886A0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DAC9B04AC0>, because it is not built.
# W0907 19:43:03.647495 21124 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001DAC9B04AC0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DAC9B04E20>, because it is not built.
# W0907 19:43:03.647495 21124 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x000001DAC9B04E20>, because it is not built.
# W0907 19:43:45.080047 21124 save.py:269] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 173). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: sign-detection\project\modelsNEW\my_sdd_mobnet\export\saved_model\assets
# I0907 19:43:59.879802 21124 builder_impl.py:779] Assets written to: sign-detection\project\modelsNEW\my_sdd_mobnet\export\saved_model\assets
# INFO:tensorflow:Writing pipeline config file to sign-detection\project\modelsNEW\my_sdd_mobnet\export\pipeline.config
# I0907 19:44:02.431074 21124 config_util.py:253] Writing pipeline config file to sign-detection\project\modelsNEW\my_sdd_mobnet\export\pipeline.config

# %%
# !pip install tensorflowjs
# Out:
# Collecting tensorflowjs
#   Using cached tensorflowjs-4.22.0-py3-none-any.whl.metadata (3.2 kB)
# Collecting flax>=0.7.2 (from tensorflowjs)
#   Using cached flax-0.8.5-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: importlib_resources>=5.9.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflowjs) (6.5.2)
# Requirement already satisfied: jax>=0.4.13 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflowjs) (0.4.30)
# Requirement already satisfied: jaxlib>=0.4.13 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflowjs) (0.4.30)
# Collecting tensorflow<3,>=2.13.0 (from tensorflowjs)
#   Using cached tensorflow-2.20.0-cp39-cp39-win_amd64.whl.metadata (4.6 kB)
# Requirement already satisfied: tf-keras>=2.13.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflowjs) (2.15.0)
# Collecting tensorflow-decision-forests>=1.5.0 (from tensorflowjs)
#   Using cached tensorflow_decision_forests-1.8.1-cp39-cp39-win_amd64.whl
# Requirement already satisfied: six<2,>=1.16.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflowjs) (1.17.0)
# Requirement already satisfied: tensorflow-hub>=0.16.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflowjs) (0.16.1)
# Requirement already satisfied: packaging~=23.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflowjs) (23.2)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.4.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.4.0)
# Collecting protobuf>=5.28.0 (from tensorflow<3,>=2.13.0->tensorflowjs)
#   Using cached protobuf-6.32.0-cp39-cp39-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.32.4)
# Requirement already satisfied: setuptools in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (78.1.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.14.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.74.0)
# Collecting tensorboard~=2.20.0 (from tensorflow<3,>=2.13.0->tensorflowjs)
#   Using cached tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting keras>=3.10.0 (from tensorflow<3,>=2.13.0->tensorflowjs)
#   Using cached keras-3.10.0-py3-none-any.whl.metadata (6.0 kB)
# Collecting numpy>=1.26.0 (from tensorflow<3,>=2.13.0->tensorflowjs)
#   Using cached numpy-2.0.2-cp39-cp39-win_amd64.whl.metadata (59 kB)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.14.0)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow<3,>=2.13.0->tensorflowjs)
#   Using cached ml_dtypes-0.5.3-cp39-cp39-win_amd64.whl.metadata (9.2 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (2025.7.14)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorboard~=2.20.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.8.2)
# Requirement already satisfied: pillow in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorboard~=2.20.0->tensorflow<3,>=2.13.0->tensorflowjs) (11.3.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.20.0->tensorflow<3,>=2.13.0->tensorflowjs)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorboard~=2.20.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from astunparse>=1.6.0->tensorflow<3,>=2.13.0->tensorflowjs) (0.45.1)
# Requirement already satisfied: msgpack in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from flax>=0.7.2->tensorflowjs) (1.1.1)
# Collecting optax (from flax>=0.7.2->tensorflowjs)
#   Using cached optax-0.2.4-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: orbax-checkpoint in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from flax>=0.7.2->tensorflowjs) (0.6.4)
# Requirement already satisfied: tensorstore in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from flax>=0.7.2->tensorflowjs) (0.1.69)
# Requirement already satisfied: rich>=11.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from flax>=0.7.2->tensorflowjs) (14.1.0)
# Requirement already satisfied: PyYAML>=5.4.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from flax>=0.7.2->tensorflowjs) (5.4.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from importlib_resources>=5.9.0->tensorflowjs) (3.23.0)
# Requirement already satisfied: scipy>=1.9 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from jax>=0.4.13->tensorflowjs) (1.13.1)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from jax>=0.4.13->tensorflowjs) (8.7.0)
# Collecting namex (from keras>=3.10.0->tensorflow<3,>=2.13.0->tensorflowjs)
#   Using cached namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.10.0->tensorflow<3,>=2.13.0->tensorflowjs)
#   Using cached optree-0.17.0-cp39-cp39-win_amd64.whl.metadata (34 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.7.2->tensorflowjs) (0.1.2)
# Requirement already satisfied: pandas in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (2.3.1)
# Collecting tensorflow<3,>=2.13.0 (from tensorflowjs)
#   Using cached tensorflow-2.15.1-cp39-cp39-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: wurlitzer in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (3.1.1)
# Collecting tensorflow-intel==2.15.1 (from tensorflow<3,>=2.13.0->tensorflowjs)
#   Using cached tensorflow_intel-2.15.1-cp39-cp39-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from jax>=0.4.13->tensorflowjs) (0.3.2)
# Requirement already satisfied: numpy>=1.21 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from ml_dtypes<1.0.0,>=0.5.1->tensorflow<3,>=2.13.0->tensorflowjs) (1.24.4)
# Collecting protobuf!=4.24.0,>=3.19.6 (from tensorboard~=2.20.0->tensorflow<3,>=2.13.0->tensorflowjs)
#   Using cached protobuf-4.25.8-cp39-cp39-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (0.27.0)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs)
#   Using cached tensorboard-2.15.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs)
#   Using cached tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.16,>=2.15.0 (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs)
#   Using cached keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (2.40.3)
# Collecting google-auth-oauthlib<2,>=0.5 (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs)
#   Using cached google_auth_oauthlib-1.2.2-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (2.0.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (3.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.0.2)
# Requirement already satisfied: chex>=0.1.87 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from optax->flax>=0.7.2->tensorflowjs) (0.1.90)
# Requirement already satisfied: etils[epy] in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from optax->flax>=0.7.2->tensorflowjs) (1.5.2)
# Requirement already satisfied: toolz>=0.9.0 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from chex>=0.1.87->optax->flax>=0.7.2->tensorflowjs) (1.0.0)
# Requirement already satisfied: nest_asyncio in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (1.6.0)
# Requirement already satisfied: humanize in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (4.13.0)
# Requirement already satisfied: fsspec in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from etils[epy]->optax->flax>=0.7.2->tensorflowjs) (2025.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\karthik\.conda\envs\gpuenv\lib\site-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2025.2)
# Using cached tensorflowjs-4.22.0-py3-none-any.whl (89 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Using cached flax-0.8.5-py3-none-any.whl (731 kB)
# Using cached tensorflow-2.15.1-cp39-cp39-win_amd64.whl (2.1 kB)
# Using cached tensorflow_intel-2.15.1-cp39-cp39-win_amd64.whl (300.8 MB)
# Using cached keras-2.15.0-py3-none-any.whl (1.7 MB)
# Using cached protobuf-4.25.8-cp39-cp39-win_amd64.whl (413 kB)
# Using cached tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
# Using cached google_auth_oauthlib-1.2.2-py3-none-any.whl (19 kB)
# Using cached tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
# Using cached optax-0.2.4-py3-none-any.whl (319 kB)
# Installing collected packages: tensorflow-estimator, tensorboard-data-server, protobuf, keras, google-auth-oauthlib, tensorboard, tensorflow-intel, optax, tensorflow, flax, tensorflow-decision-forests, tensorflowjs
#
#   Attempting uninstall: tensorflow-estimator
#
#     Found existing installation: tensorflow-estimator 2.10.0
#
#    ----------------------------------------  0/12 [tensorflow-estimator]
#     Uninstalling tensorflow-estimator-2.10.0:
#    ----------------------------------------  0/12 [tensorflow-estimator]
#       Successfully uninstalled tensorflow-estimator-2.10.0
#    ----------------------------------------  0/12 [tensorflow-estimator]
#    ----------------------------------------  0/12 [tensorflow-estimator]
#    ----------------------------------------  0/12 [tensorflow-estimator]
#    ----------------------------------------  0/12 [tensorflow-estimator]
#    ----------------------------------------  0/12 [tensorflow-estimator]
#    ----------------------------------------  0/12 [tensorflow-estimator]
#    ----------------------------------------  0/12 [tensorflow-estimator]
#    ----------------------------------------  0/12 [tensorflow-estimator]
#    ----------------------------------------  0/12 [tensorflow-estimator]
#    ----------------------------------------  0/12 [tensorflow-estimator]
#    ----------------------------------------  0/12 [tensorflow-estimator]
#    ----------------------------------------  0/12 [tensorflow-estimator]
#    ----------------------------------------  0/12 [tensorflow-estimator]
#    ----------------------------------------  0/12 [tensorflow-estimator]
#    ----------------------------------------  0/12 [tensorflow-estimator]
#    ----------------------------------------  0/12 [tensorflow-estimator]
#    ----------------------------------------  0/12 [tensorflow-estimator]
#    ----------------------------------------  0/12 [tensorflow-estimator]
#    ----------------------------------------  0/12 [tensorflow-estimator]
#    ----------------------------------------  0/12 [tensorflow-estimator]
#    ----------------------------------------  0/12 [tensorflow-estimator]
#    ----------------------------------------  0/12 [tensorflow-estimator]
#    ----------------------------------------  0/12 [tensorflow-estimator]
#   Attempting uninstall: tensorboard-data-server
#    ----------------------------------------  0/12 [tensorflow-estimator]
#     Found existing installation: tensorboard-data-server 0.6.1
#    ----------------------------------------  0/12 [tensorflow-estimator]
#     Uninstalling tensorboard-data-server-0.6.1:
#    ----------------------------------------  0/12 [tensorflow-estimator]
#       Successfully uninstalled tensorboard-data-server-0.6.1
#    ----------------------------------------  0/12 [tensorflow-estimator]
#    --- ------------------------------------  1/12 [tensorboard-data-server]
#   Attempting uninstall: protobuf
#    --- ------------------------------------  1/12 [tensorboard-data-server]
#     Found existing installation: protobuf 3.19.6
#    --- ------------------------------------  1/12 [tensorboard-data-server]
#     Uninstalling protobuf-3.19.6:
#    --- ------------------------------------  1/12 [tensorboard-data-server]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#       Successfully uninstalled protobuf-3.19.6
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#   Attempting uninstall: keras
#    ------ ---------------------------------  2/12 [protobuf]
#     Found existing installation: keras 2.10.0
#    ------ ---------------------------------  2/12 [protobuf]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#     Uninstalling keras-2.10.0:
#    ---------- -----------------------------  3/12 [keras]
#       Successfully uninstalled keras-2.10.0
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#    ---------- -----------------------------  3/12 [keras]
#   Attempting uninstall: google-auth-oauthlib
#    ---------- -----------------------------  3/12 [keras]
#     Found existing installation: google-auth-oauthlib 0.4.6
#    ---------- -----------------------------  3/12 [keras]
#     Uninstalling google-auth-oauthlib-0.4.6:
#    ---------- -----------------------------  3/12 [keras]
#       Successfully uninstalled google-auth-oauthlib-0.4.6
#    ---------- -----------------------------  3/12 [keras]
#    ------------- --------------------------  4/12 [google-auth-oauthlib]
#    ------------- --------------------------  4/12 [google-auth-oauthlib]
#    ------------- --------------------------  4/12 [google-auth-oauthlib]
#   Attempting uninstall: tensorboard
#    ------------- --------------------------  4/12 [google-auth-oauthlib]
#     Found existing installation: tensorboard 2.10.1
#    ------------- --------------------------  4/12 [google-auth-oauthlib]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#     Uninstalling tensorboard-2.10.1:
#    ---------------- -----------------------  5/12 [tensorboard]
#       Successfully uninstalled tensorboard-2.10.1
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    ---------------- -----------------------  5/12 [tensorboard]
#    -------------------- -------------------  6/12 [tensorflow-intel]
#    -------------------- -------------------  6/12 [tensorflow-intel]
#    -------------------- -------------------  6/12 [tensorflow-intel]
#    -------------------- -------------------  6/12 [tensorflow-intel]
#    -------------------- -------------------  6/12 [tensorflow-intel]
#    -------------------- -------------------  6/12 [tensorflow-intel]
#    -------------------- -------------------  6/12 [tensorflow-intel]
#    -------------------- -------------------  6/12 [tensorflow-intel]
#    -------------------- -------------------  6/12 [tensorflow-intel]
#    -------------------- -------------------  6/12 [tensorflow-intel]
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\karthik\.conda\envs\gpuenv\Lib\site-packages\google\~-otobuf'.
#   You can safely remove it manually.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\karthik\\.conda\\envs\\gpuenv\\Lib\\site-packages\\tensorflow\\compiler\\tf2tensorrt\\_pywrap_py_utils.pyd'
# Consider using the `--user` option or check the permissions.

# %%
command = "tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default {} {}".format(os.path.join(paths['OUTPUT_PATH'], 'saved_model'), paths['TFJS_PATH'])

# %%
print(command)
# Out:
# tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default sign-detection\project\modelsNEW\my_sdd_mobnet\export\saved_model sign-detection\project\modelsNEW\my_sdd_mobnet\tfjsexport

# %%
# !{command}

# %%
TFLITE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'export_tflite_graph_tf2.py ')
command = "python {} --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(TFLITE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['TFLITE_PATH'])
print(command)
# Out:
# python sign-detection\modelsNEW\research\object_detection\export_tflite_graph_tf2.py  --pipeline_config_path=sign-detection\project\modelsNEW\my_sdd_mobnet\pipeline.config --trained_checkpoint_dir=sign-detection\project\modelsNEW\my_sdd_mobnet --output_directory=sign-detection\project\modelsNEW\my_sdd_mobnet\tfliteexport

# %%
# !{command}

# %%
FROZEN_TFLITE_PATH = os.path.join(paths['TFLITE_PATH'], 'saved_model')
TFLITE_MODEL = os.path.join(paths['TFLITE_PATH'], 'saved_model', 'detect.tflite')
command = "tflite_convert \
--saved_model_dir={} \
--output_file={} \
--input_shapes=1,300,300,3 \
--input_arrays=normalized_input_image_tensor \
--output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' \
--inference_type=FLOAT \
--allow_custom_ops".format(FROZEN_TFLITE_PATH, TFLITE_MODEL, )
print(command)

# %%
# !{command}

# %%
# !tar -czf models.tar.gz {paths['CHECKPOINT_PATH']}
from google.colab import drive
drive.mount('/content/drive')
